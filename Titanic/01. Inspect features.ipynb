# %%
# %pylab inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Index
# * [Survive vs. Sex](#Survive-vs.-Sex)
# * [Survive vs. Pclass](#Survive-vs.-Pclass)
# * [Survive vs. Ticket](#Survive-vs.-Ticket)

# %%
train_df = pd.read_csv("train_processed.csv",index_col="PassengerId")

# %% [markdown]
# ### Survive vs. Sex

# %%
import common
common.survive_cross_tab(train_df,"Sex")
# Out:
# **************** counts
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109
# **************** Survive across Sex
# Sex         female      male
# Survived
# 0         0.147541  0.852459
# 1         0.681287  0.318713
# **************** Sex across Survive
# Survived         0         1
# Sex
# female    0.257962  0.742038
# male      0.811092  0.188908

# %% [markdown]
# ### Survive vs. Pclass

# %%
common.survive_cross_tab(train_df,"Pclass")
# Out:
# **************** counts
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119
# **************** Survive across Pclass
# Pclass           1         2         3
# Survived
# 0         0.145719  0.176685  0.677596
# 1         0.397661  0.254386  0.347953
# **************** Pclass across Survive
# Survived         0         1
# Pclass
# 1         0.370370  0.629630
# 2         0.527174  0.472826
# 3         0.757637  0.242363

# %% [markdown]
# ### Survive vs. Ticket

# %%
common.survive_cross_tab(train_df,"TicketGroup",(15,4))
# Out:
# **************** counts
# TicketGroup  4digit  5digit  6digit  7digit   A   C  F  Others   P   S   W
# Survived
# 0                61      50     282      12  27  31  3       5  23  44  11
# 1                36      81     133       4   2  16  4       1  42  21   2
# **************** Survive across TicketGroup
# TicketGroup    4digit    5digit    6digit    7digit         A         C  \
# Survived
# 0            0.111111  0.091075  0.513661  0.021858  0.049180  0.056466
# 1            0.105263  0.236842  0.388889  0.011696  0.005848  0.046784
#
# TicketGroup         F    Others         P         S         W
# Survived
# 0            0.005464  0.009107  0.041894  0.080146  0.020036
# 1            0.011696  0.002924  0.122807  0.061404  0.005848
# **************** TicketGroup across Survive
# Survived            0         1
# TicketGroup
# 4digit       0.628866  0.371134
# 5digit       0.381679  0.618321
# 6digit       0.679518  0.320482
# 7digit       0.750000  0.250000
# ...
